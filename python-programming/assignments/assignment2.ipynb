# %% [markdown]
# #### 1. Write a program that uses input to prompt a user for their name and then welcomes them.

# %%
hello= input("Enter your name :")
print(f"Hello {hello}")
# Out:
# Hello 4

# %% [markdown]
# #### 2.  Write a program to prompt the user for hours and rate per hour to compute gross pay.
#
# Enter Hours: 35
# Enter Rate: 2.75
# Pay: 96.25

# %%
hours=float(input("Enter Hours worked :"))
rate=float(input("Enter your rates :"))
pay = hours * rate #payrate
print(f"Pay :{pay}")
# Out:
# Pay :25.0

# %% [markdown]
# #### 3. Assume that we execute the following assignment statements:
# python
#
# width = 17
#
# height = 12.0
#
# For each of the following expressions, write the value of the expression and the type (of the value of the expression). Use the Python interpreter to check your answers.
#
# width//2
#
# width/2.0
#
# height/3
#
# 1 + 2 * 5

# %%
width = 17
height = 12.0

findingfloor=width//2
decimaldivison=width/2.0
intergerdiv=width/3
expression=1+2*5

print(f"Value : {findingfloor} Type : {type(findingfloor)}")
print(f"Value : {decimaldivison} Type : {type(decimaldivison)}")
print(f"Value : {intergerdiv} Type : {type(intergerdiv)}")
print(f"Value : {expression} Type : {type(expression)}")
# Out:
# Value : 8 Type : <class 'int'>
# Value : 8.5 Type : <class 'float'>
# Value : 5.666666666666667 Type : <class 'float'>
# Value : 11 Type : <class 'int'>

# %% [markdown]
# #### 4. Write a program which prompts the user for a Celsius temperature, convert the temperature to Fahrenheit, and print out the converted temperature.

# %%
temp=float((input("Enter Temp in degrees:")))
temp_farehn= temp*(9/5)+32 #formula to farenheit 
print(f"{temp}°C , is converted to {temp_farehn} f ")
# Out:
# 1.0°C , is converted to 33.8 f
